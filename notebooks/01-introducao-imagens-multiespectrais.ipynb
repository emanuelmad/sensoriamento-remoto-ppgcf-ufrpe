# %% [markdown]
# # 01 | Introducao a imagens multiespectrais
#
# Este notebook introduz a ideia de bandas, pixel e composicao colorida usando uma cena sintetica.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve().parent
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

from scripts.rs_utils import describe_band, make_synthetic_scene, plot_rgb

# %%
scene = make_synthetic_scene(height=220, width=220, seed=7)
scene.keys()

# %%
for band_name in ["blue", "green", "red", "nir", "swir1"]:
    print(band_name, describe_band(scene[band_name]))

# %%
plot_rgb(scene["red"], scene["green"], scene["blue"], title="Composicao RGB sintetica")

# %% [markdown]
# ## Exercicios sugeridos
#
# 1. Compare a distribuicao numerica das bandas.
# 2. Discuta por que o NIR se destaca em vegetacao.
# 3. Troque a ordem das bandas na composicao e observe a mudanca visual.
